# %%
from Alice_Data_Scraper import AliceBlueDataScraper  # Adjust import based on your folder structure
from datetime import datetime, timedelta
import os

# %%
scraper = AliceBlueDataScraper()
# Out:
# AliceBlueDataScraper initialized with user_id: 1916207
# AliceBlueDataScraper initialized with api_key: AIo9L5aqD8NRfRMZ4z5PmfK1iI0GB17VslusiaI51t0NDufuljl9xKWsVDpKWxvXznAqQEMDqZc2ZDtaJgHILlBfDb9ORaJ9xLmso9S0HXLQd1b4fbLWBT3JBZe6OdMR

# %%
scraper.Check_Login_info()
# Out:
# --- AliceBlue Profile Information ---
# Account Name   : BHARAT SHARMA
# Account ID     : 1916207
# Account Status : Activated
# Broker Name    : ALICEBLUE
# Products       : CNC, NRML, MIS, MTF, CO, BO
# Email          : Bharat05122002@gmail.com
# Phone          : 9868009203
# Demat Type     : NA
# POA Status     : Not Given

# %%
symbol = "TCS"
timeframe_provided = "1"  # 1 minute data
from_date = datetime(2020, 1, 1)  # Start date for historical data
to_date = datetime.now()  # Current date for historical data
file_path = "./../data/TCS.csv"  # Path to save the historical data
indices_require = False  # Whether to include index data or not

directory = os.path.dirname(file_path)
if directory and not os.path.exists(directory):
    os.makedirs(directory)
    
scraper.get_and_store_historical_data(
	symbol=symbol,
	timeframe_provided=timeframe_provided,
	from_date= from_date,
	to_date=to_date,
	file_path=file_path,
	indices_require=indices_require
)
# Out:
# Fetching historical data for symbol: 'TCS'
#   Timeframe : 1
#   From      : 2020-01-01 00:00:00
#   To        : 2025-07-28 16:46:01.859477
#   Exchange  : NSE
#   Indices   : False
#   Save to   : ./../data/TCS.csv
#
# NOTE: Today's contract master file will be updated after 08:00 AM. Before 08:00 AM previous day contract file be downloaded.
# Historical data for TCS from 2020-01-01 00:00:00 to 2025-07-28 16:46:01.859477 saved to ./../data/TCS.csv.
#                   datetime     open     high     low    close   volume
# 0      2019-12-26 09:15:00  2216.40  2222.00  2216.0  2219.65  28186.0
# 1      2019-12-26 09:16:00  2219.80  2229.00  2219.8  2221.95  27256.0
# 2      2019-12-26 09:17:00  2221.95  2222.00  2217.0  2218.50  11108.0
# 3      2019-12-26 09:18:00  2218.50  2218.75  2217.0  2217.00  10371.0
# 4      2019-12-26 09:19:00  2217.15  2217.15  2211.3  2211.30  14148.0
# ...                    ...      ...      ...     ...      ...      ...
# 55121  2025-07-28 15:25:59  3079.60  3080.00  3079.6  3080.00  17175.0
# 55122  2025-07-28 15:26:59  3079.80  3080.40  3079.2  3080.30  67750.0
# 55123  2025-07-28 15:27:59  3080.20  3083.00  3080.1  3082.40  26252.0
# 55124  2025-07-28 15:28:59  3081.40  3082.80  3078.1  3081.80  35496.0
# 55125  2025-07-28 15:29:59  3082.80  3085.80  3076.2  3085.80  11988.0
#
# [55126 rows x 6 columns]
